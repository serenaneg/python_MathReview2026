# %% [markdown]
# # Simple Python — first commands
#
# Run each cell with **Shift + Enter**. Read the comment, run it, change a number and run again.

# %% [markdown]
# ## 1. Import packages
# A **package** is a toolbox of ready-made code. Import at the top.

# %%
# Import numpy as np and matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Variables and types
# A variable stores a value. `type()` tells you what kind it is.

# %%
# Make a variable name = "Woods Hole", depth = 45, temp = 12.5
# print them, then print type(depth)

# %% [markdown]
# ## 3. Math
# Python is a calculator. `**` is power, `%` is remainder.

# %%
# Try: 2 + 3, 10 / 4, 2 ** 3 (power), 17 % 5 (remainder)

# %% [markdown]
# ## 4. Lists
# A list holds many values in order. Counting starts at **0**.

# %%
# Make a list depths = [10, 25, 40, 55]
# print the first item, the last item, and how many (len)
# then append 70 and print the list

# %% [markdown]
# ## 5. A loop
# Do something once for each item.

# %%
# Loop over depths and print each one

# %% [markdown]
# ## 6. A condition
# Do different things depending on a test.

# %%
# Set d = 55. If d > 50 print "deep", else print "shallow"

# %% [markdown]
# ## 7. A function
# A reusable recipe: give it input, get output back.

# %%
# Write a function to_fahrenheit(celsius) that returns celsius * 9/5 + 32
# then call it with 12.5

# %% [markdown]
# ## 8. NumPy arrays
# Like a list, but built for math on many numbers at once.

# %%
# Make a = np.array([10, 25, 40, 55])
# print a.mean(), a.max(), and a * 2

# %% [markdown]
# ## 9. A quick plot

# %%
# Make x = np.array([0,1,2,3,4]) and y = x ** 2
# plt.plot(x, y, marker="o"), add labels/title, then plt.show()

# %% [markdown]
# ## Your turn 🎯
# 1. Add another depth to the list and re-run the loop.
# 2. Change the function to convert Celsius to Kelvin (`+ 273.15`).
# 3. Plot `y = x ** 3` instead of `x ** 2`.
